# %%
import pager
from pager.pager_pipe_line import pdf2region_row

# %%
from pager.doc_model import MinerPDFModel, PrecisionPDFModel

# %%
pdf_reader = PrecisionPDFModel({"page_model": pdf2region_row})

# %%
pdf_reader.read_from_file('../tests/files/text_header_table.pdf')

# %%
pdf_reader.extract()
# Out:
# 7
# /home/daniil/project/PageR/env/lib/python3.12/site-packages/torch_geometric/nn/conv/tag_conv.py:102: UserWarning: Converting sparse tensor to CSR format for more efficient processing. Consider converting your sparse tensor to CSR format beforehand to avoid repeated conversion (got 'torch.sparse_coo')
#   return spmm(adj_t, x, reduce=self.aggr)
# /home/daniil/project/PageR/env/lib/python3.12/site-packages/torch/nn/modules/module.py:1775: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   return self._call_impl(*args, **kwargs)

# %%
document = pdf_reader.document

# %%
regions = [reg for page in document.pages for reg in page.regions]

# %%
print(document.md)
# Out:
# # Заголовок 1 Заголовок 2
#
# ...

# %% [markdown]
# # Заголовок 1
#
# # Заголовок 2
#
# Принимая во внимание показатели успешности, повышение уровня гражданского сознания напрямую зависит от переосмысления внешнеэкономических политик. В своём стремлении улучшить пользовательский опыт мы упускаем, что явные признаки победы институционализации неоднозначны и будут представлены в исключительно положительном свете.
#
# Учитывая ключевые сценарии поведения, консультация с широким активом предполагает независимые способы реализации кластеризации усилий. Картельные сговоры не допускают ситуации, при которой явные признаки победы институционализации являются только методом политического участия и ограничены исключительно образом мышления. Господа, социально-экономическое развитие напрямую зависит от благоприятных перспектив. Внезапно, непосредственные участники технического прогресса неоднозначны и будут представлены в исключительно положительном свете. Есть над чем задуматься: стремящиеся вытеснить традиционное производство, нанотехнологии являются только методом политического участия и разоблачены.
#
# # Заголовок 3
#
# Принимая во внимание показатели успешности, сплочённость команды профессионалов не оставляет шанса для укрепления моральных ценностей. Равным образом, высококачественный прототип будущего проекта способствует подготовке и реализации системы обучения кадров, соответствующей насущным потребностям. Как уже неоднократно упомянуто, тщательные исследования конкурентов, вне зависимости от их уровня, должны быть превращены в посмешище, хотя само их существование приносит несомненную пользу обществу. В целом, конечно, граница обучения кадров требует определения и уточнения первоочередных требований.
#
# Как уже неоднократно упомянуто, сделанные на базе интернет-аналитики выводы своевременно верифицированы. Лишь базовые сценарии поведения пользователей могут быть подвергнуты целой серии независимых исследований.
#
# Строка 1
#
# Строка 2
#
# Колонка 2 Колонка 3 Колонка 4 Слово 1 Слово 2 Слово 5 Слово 4 Слово 3
#
#
# <!-- page_num: 0 -->
# ---

# %%
def is_content(reg):
    if reg.label is 'header':
        return False
    return True


def get_tree_from_doc(document):
    regions = [reg for page in document.pages for reg in page.regions]
    # regions.sort(key=lambda x: x.order)
    # (n1, n2) : n1 -> n2
    N = len(regions)
    order_edges = [(-1, 0)] + [(i, i+1) for i in range(N-1)]
    parent_edges = []


    tmp_parent_list_id = [-1] # -1 is id Document
    

    # region_embs = {i:get_embedding(reg) for i, reg in enumerate(regions)}
    def is_include_by_id(parent_id, child_id):
        if parent_id == -1:
            return True
        return regions[parent_id].style > regions[child_id].style

    for id_reg, reg  in enumerate(regions):
        test_parent_id = tmp_parent_list_id[-1]

        # Поместить контент
        if is_content(reg):
            parent_edges.append((test_parent_id, id_reg))
            continue
        
        # Работа с заголовками
        while not is_include_by_id(test_parent_id, id_reg):
            tmp_parent_list_id.pop(-1)
            test_parent_id = tmp_parent_list_id[-1]

        parent_edges.append((test_parent_id, id_reg))
        tmp_parent_list_id.append(id_reg)


    return {
        "nodes": {
            "document": {
                "name": document.name
            },
            "regions": {id_reg: reg.to_dict()
                for id_reg, reg  in enumerate(regions)
            }
        },
        "edges": {
            "order": order_edges,
            "parental": parent_edges
        }
    }
# Out:
# <>:2: SyntaxWarning: "is" with 'str' literal. Did you mean "=="?
# <>:2: SyntaxWarning: "is" with 'str' literal. Did you mean "=="?
# /tmp/ipykernel_47271/2234354136.py:2: SyntaxWarning: "is" with 'str' literal. Did you mean "=="?
#   if reg.label is 'header':

# %%
# get_tree_from_doc(document)

# %%
document.pages[0].regions[0].rows[0].font_name

# %%
pdf_reader.pdf_json
# Out:
# {'pages': [{'number': 0,
#    'tables': [],
#    'images': [],
#    'width': 595.303955078125,
#    'rows': [{'segment': {'x_top_left': 56,
#       'y_top_left': 71,
#       'width': 107,
#       'height': 17},
#      'words': [{'metadata': 'unknown',
#        'segment': {'x_top_left': 56,
#         'y_top_left': 71,
#         'width': 92,
#         'height': 17},
#        'text': 'Заголовок',
#        'url': '',
#        'font': {'is_italic': False,
#         'is_normal': False,
#         'font_size': 18,
#         'is_bold': True,
#         'font_name': 'BAAAAA+LiberationSans-Bold'}},
#       {'metadata': 'unknown',
#        'segment': {'x_top_left': 153,
#         'y_top_left': 71,
#         'width': 10,
#         'height': 17},
#        'text': '1',
#        'url': '',
#        'font': {'is_italic': False,
#         'is_normal': False,
#         'font_size': 18,
#         'is_bold': True,
#         'font_name': 'BAAAAA+LiberationSans-Bold'}}],
#      'text': 'Заголовок 1'},
# ...
